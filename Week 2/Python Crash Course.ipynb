# %%
import numpy as np

# %%
import pandas as pd

# %%
labels = ['a','b','c']
my_data = [10,20,30]

arr = np.array(my_data)
d = {'a':10,'b':20,'c':30}

# %%
d
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %% [markdown]
# ### Series

# %%
pd.Series(data=my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_data, index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_data, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
d
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(data = [sum, print, len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
ser1 = pd.Series([1,2,3,4], ['USA', 'Germany', 'USSR', 'Japon'])

# %%
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japon      4
# dtype: int64

# %%
ser2 = pd.Series([1,2,5,3],['USA', 'Germany', 'USSR', 'Japon'] )
ser2
# Out:
# USA        1
# Germany    2
# USSR       5
# Japon      3
# dtype: int64

# %%
ser2['Germany']
# Out:
# 2

# %%
ser2[1]
# Out:
# 2

# %%
ser3 = pd.Series(labels)
ser3
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object
